# %% [markdown]
# # Project:  TMDb-Movies Data Analysis
# Adel Abu Hashim - May 2020
#
# ## Table of Contents
# <ul>
# <li><a href="#intro">Introduction</a></li>
# <li><a href="#wrangling">Data Wrangling</a></li>
# <li><a href="#clean">Data Cleaning</a></li>
# <li><a href="#eda">Exploratory Data Analysis</a></li>
# <li><a href="#conclusions">Conclusions</a></li>
# </ul>

# %% [markdown]
# <a id='intro'></a>
# ## Introduction
#
#
# >In this project; I used tmdb-movies data set from kaggle; This data set contains information about 10,000 movies collected from The Movie Database (TMDb), including user ratings and revenue.
#
#
# >***Quetions***
# 1. Q1: Which movies made maximum and minimum and minimum profits?
# 2. Q2: Who is most movie director?
# 3. Q3: In which year there was most profit?
# 4. Q4: What is most geners in movies?
# 5. Q5: What is the relation between profits over years?

# %%
#import dependencies
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
# load data int DataFrame
df = pd.read_csv('tmdb-movies.csv')

# %% [markdown]
# <a id='wrangling'></a>
# ## Data Wrangling

# %% [markdown]
# >### General Properties

# %%
#print the first row of df
df.head(1)
# Out:
#        id    imdb_id  popularity     budget     revenue  original_title  \
# 0  135397  tt0369610   32.985763  150000000  1513528810  Jurassic World
#
#                                                 cast  \
# 0  Chris Pratt|Bryce Dallas Howard|Irrfan Khan|Vi...
#
#                         homepage         director            tagline  ...  \
# 0  http://www.jurassicworld.com/  Colin Trevorrow  The park is open.  ...
#
#                                             overview runtime  \
# 0  Twenty-two years after the events of Jurassic ...     124
#
#                                       genres  \
# 0  Action|Adventure|Science Fiction|Thriller
#
#                                 production_companies release_date vote_count  \
# 0  Universal Studios|Amblin Entertainment|Legenda...       6/9/15       5562
#
#    vote_average  release_year    budget_adj   revenue_adj
# 0           6.5          2015  1.379999e+08  1.392446e+09
#
# [1 rows x 21 columns]

# %%
#print df's statiscs
df.describe()
# Out:
#                   id    popularity        budget       revenue       runtime  \
# count   10866.000000  10866.000000  1.086600e+04  1.086600e+04  10866.000000
# mean    66064.177434      0.646441  1.462570e+07  3.982332e+07    102.070863
# std     92130.136561      1.000185  3.091321e+07  1.170035e+08     31.381405
# min         5.000000      0.000065  0.000000e+00  0.000000e+00      0.000000
# 25%     10596.250000      0.207583  0.000000e+00  0.000000e+00     90.000000
# 50%     20669.000000      0.383856  0.000000e+00  0.000000e+00     99.000000
# 75%     75610.000000      0.713817  1.500000e+07  2.400000e+07    111.000000
# max    417859.000000     32.985763  4.250000e+08  2.781506e+09    900.000000
#
#          vote_count  vote_average  release_year    budget_adj   revenue_adj
# count  10866.000000  10866.000000  10866.000000  1.086600e+04  1.086600e+04
# mean     217.389748      5.974922   2001.322658  1.755104e+07  5.136436e+07
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 21 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    10866 non-null  int64
#  1   imdb_id               10856 non-null  object
#  2   popularity            10866 non-null  float64
#  3   budget                10866 non-null  int64
#  4   revenue               10866 non-null  int64
#  5   original_title        10866 non-null  object
#  6   cast                  10790 non-null  object
#  7   homepage              2936 non-null   object
#  8   director              10822 non-null  object
#  9   tagline               8042 non-null   object
#  10  keywords              9373 non-null   object
#  11  overview              10862 non-null  object
#  12  runtime               10866 non-null  int64
#  13  genres                10843 non-null  object
#  14  production_companies  9836 non-null   object
# ...

# %% [markdown]
# <a id='clean'></a>
# # Data Cleaning

# %% [markdown]
# >### Drop Extraneous Columns

# %%
# list of Extraneous Columns
extraneous_columns = ['id', 'imdb_id', 'homepage', 'tagline', 'keywords', 'overview', 'budget_adj',
       'revenue_adj', 'vote_count', 'vote_average', 'production_companies', 'cast']
df.drop(extraneous_columns, axis=1, inplace=True)

# %%
df.head(1)
# Out:
#    popularity     budget     revenue  original_title         director  \
# 0   32.985763  150000000  1513528810  Jurassic World  Colin Trevorrow
#
#    runtime                                     genres release_date  \
# 0      124  Action|Adventure|Science Fiction|Thriller       6/9/15
#
#    release_year
# 0          2015

# %%
# rearange the order of columns
ordered_columns = ['original_title', 'release_year','release_date', 'runtime', 
                   'director','genres','popularity', 'budget', 'revenue']

df = df.reindex(columns = ordered_columns)

# %%
df.head(1)
# Out:
#    original_title  release_year release_date  runtime         director  \
# 0  Jurassic World          2015       6/9/15      124  Colin Trevorrow
#
#                                       genres  popularity     budget  \
# 0  Action|Adventure|Science Fiction|Thriller   32.985763  150000000
#
#       revenue
# 0  1513528810

# %% [markdown]
# >### Fix date format

# %%
# make new dataframe for dates
dates = df[['release_year', 'release_date']].copy()
dates.head(1)
# Out:
#    release_year release_date
# 0          2015       6/9/15

# %%
#extract day and month from realeas date
dates[['month','day','bad_year']] = dates.release_date.str.split("/",expand=True) 
dates.head(1)
# Out:
#    release_year release_date month day bad_year
# 0          2015       6/9/15     6   9       15

# %%
dates.dtypes
# Out:
# release_year     int64
# release_date    object
# month           object
# day             object
# bad_year        object
# dtype: object

# %%
# convert object(string) into integer
dates['release_year'] = dates['release_year'].astype(str)
dates.dtypes
# Out:
# release_year    object
# release_date    object
# month           object
# day             object
# bad_year        object
# dtype: object

# %%
# make right date type for date
dates['date'] = dates['release_year'] + '-' + dates['month'] + '-' + dates['day']
dates['date'] = pd.to_datetime(dates['date'])
dates.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 6 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   release_year  10866 non-null  object
#  1   release_date  10866 non-null  object
#  2   month         10866 non-null  object
#  3   day           10866 non-null  object
#  4   bad_year      10866 non-null  object
#  5   date          10866 non-null  datetime64[ns]
# dtypes: datetime64[ns](1), object(5)
# memory usage: 509.5+ KB

# %%
# fix dates in original dataframe
df['release_date'] = dates['date']

# %%
df.head(1)
# Out:
#    original_title  release_year release_date  runtime         director  \
# 0  Jurassic World          2015   2015-06-09      124  Colin Trevorrow
#
#                                       genres  popularity     budget  \
# 0  Action|Adventure|Science Fiction|Thriller   32.985763  150000000
#
#       revenue
# 0  1513528810

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10866 entries, 0 to 10865
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   original_title  10866 non-null  object
#  1   release_year    10866 non-null  int64
#  2   release_date    10866 non-null  datetime64[ns]
#  3   runtime         10866 non-null  int64
#  4   director        10822 non-null  object
#  5   genres          10843 non-null  object
#  6   popularity      10866 non-null  float64
#  7   budget          10866 non-null  int64
#  8   revenue         10866 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(4), object(3)
# memory usage: 764.1+ KB

# %% [markdown]
# >###  Drop Null Values

# %%
df.dropna(inplace=True)
df.isnull().sum()
# Out:
# original_title    0
# release_year      0
# release_date      0
# runtime           0
# director          0
# genres            0
# popularity        0
# budget            0
# revenue           0
# dtype: int64

# %%
df.head(1)
# Out:
#    original_title  release_year release_date  runtime         director  \
# 0  Jurassic World          2015   2015-06-09      124  Colin Trevorrow
#
#                                       genres  popularity     budget  \
# 0  Action|Adventure|Science Fiction|Thriller   32.985763  150000000
#
#       revenue
# 0  1513528810

# %% [markdown]
# <a id='eda'></a>
# ## Exploratory Data Analysis
#
#
#
# >### Research Question 1 (Which movies made maximum and minimum profits?)

# %%
#for maximum profit
df['profit'] = df['revenue'] - df['budget']
df_max = df[df['profit'] == df['profit'].max()]

# %%
#for minimum profit
df_min = df[df['profit'] == df['profit'].min()]

# %% [markdown]
# The best profit was made by **AVATAR**
# The worst profit was made by **The Warrior's Way**

# %% [markdown]
# ### Research Question 2  (who is most movie director?)

# %%
df.director.mode()
# Out:
# 0    Woody Allen
# dtype: object

# %% [markdown]
# most director to direct movies is ***Woody Allen***

# %% [markdown]
# ### Research Question 3  (In which year there was most profit?)

# %%
df.groupby('release_year').mean()['profit'].plot(kind='line', figsize = (10,10), color = 'orange',legend='profit')
plt.ylabel ('profit')
plt.title ('profits Vs release year')
# Out:
# Text(0.5, 1.0, 'profits Vs release year')

# %%
df.groupby('release_year').mean()['profit'].sort_values(ascending=False)
# Out:
# release_year
# 1995    3.615205e+07
# 1977    3.542111e+07
# 1992    3.486006e+07
# 2002    3.289090e+07
# 2001    3.223294e+07
# 2003    3.166685e+07
# 2004    3.134685e+07
# 1997    3.091145e+07
# 2015    3.071459e+07
# 1990    3.049428e+07
# 1989    3.003873e+07
# 1993    2.924024e+07
# 2012    2.821746e+07
# 2011    2.723087e+07
# 2007    2.707149e+07
# 1994    2.644686e+07
# 2010    2.619791e+07
# 2009    2.573738e+07
# 2005    2.527149e+07
# 1979    2.508738e+07
# 1999    2.495749e+07
# 1982    2.494628e+07
# 1991    2.436366e+07
# 2008    2.385986e+07
# 1998    2.377864e+07
# 2013    2.373097e+07
# 2014    2.364166e+07
# 2000    2.312390e+07
# 1996    2.278054e+07
# 1983    2.235527e+07
# 1987    2.202119e+07
# 2006    2.198420e+07
# 1973    2.106891e+07
# 1975    2.048207e+07
# 1985    1.969492e+07
# 1988    1.954308e+07
# 1986    1.899376e+07
# 1984    1.815536e+07
# 1980    1.802772e+07
# 1978    1.785819e+07
# 1981    1.708352e+07
# 1967    1.633801e+07
# ...

# %% [markdown]
# most average profits was in ***1995***

# %% [markdown]
# ### Research Question 4 (what is most  geners in movies?)

# %%
def split_compound_columns(column):
    """Split columns which has data like this; a|b|c
    Argument: column need to be seperated by '|' 
    Returns: Column of all seperated values;
    a
    b
    c
    """
    
    column = df[column].str.cat(sep = '|')
    splitted_column = pd.Series(column.split('|'))
    return splitted_column

# %%
genres = split_compound_columns('genres')
genres.value_counts().plot.pie( subplots=True,figsize=(20,20), legend=True, autopct='%.1f%%',title='a')
plt.title('Movies categories')
# Out:
# Text(0.5, 1.0, 'Movies categories')

# %% [markdown]
# most popular categories are ***Drama***, ***Comedey*** and ***Thriller***

# %% [markdown]
# ### Research Question 5 (What is the relation between profits over years?)

# %%
df.plot(x= 'release_year' ,y= 'profit' ,kind= 'scatter', color='orange', figsize=(10,10),legend='profit')
plt.title('Relation between each year realease and Profits')
# Out:
# Text(0.5, 1.0, 'Relation between each year realease and Profits')

# %% [markdown]
# it seems to be **Positive correlation** between ***release_year*** and ***profit***

# %%
df.corr()
# Out:
#               release_year   runtime  popularity    budget   revenue    profit
# release_year      1.000000 -0.117172    0.091347  0.117470  0.058068  0.032752
# runtime          -0.117172  1.000000    0.140527  0.193883  0.165239  0.138113
# popularity        0.091347  0.140527    1.000000  0.544858  0.663094  0.628833
# budget            0.117470  0.193883    0.544858  1.000000  0.734685  0.569941
# revenue           0.058068  0.165239    0.663094  0.734685  1.000000  0.976165
# profit            0.032752  0.138113    0.628833  0.569941  0.976165  1.000000

# %% [markdown]
# ##  correlation matrix for DataFrame

# %%
fig, ax = plt.subplots(figsize=(15,10))         
sns.heatmap(df.corr(), annot=True, fmt="f",ax=ax)
plt.title('correlation matrix for DataFrame')
# Out:
# Text(0.5, 1, 'correlation matrix for DataFrame')

# %% [markdown]
# <a id='conclusions'></a>
# ## Conclusions
#
# >## Results:
#
#
#
#     - High budget doesn't always lead to high profits
#     - Eventhough currency value change; OLD BUT GOLD movies made high profits from new one.
#     - People love Drama, Comedy, Action and Thriller movies.
#     - people hate foriegnand war and history movies.
#     so Due to make a high profits movies we should consider these things:
#         1. Make combination of m ost popular categories like( Comedy|Drama|Action).
#         2. The piriority not always for High buget.
#         3. Choose Good Cast.
#         4. Choose Most popular directors.
#
#
# >## Limitatins:
#     - Some data are not consistent; like actors and generes and some other data before cleaning process.
#     - Yhose multivalued columns make it hard to grouping data with cast or production copany for example.
#     - Some missing value (Nulls) and Not Unified shape for movie url made it hard to invetigate data by url.
#     - Some profits are negative  which problem for som stasticts.
